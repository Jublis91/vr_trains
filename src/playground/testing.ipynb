# %%
"# VR Trains playground\n",
"\n",
"Tällä notebookilla voit kokeilla DuckDB-yhteyttä ja tehdä ensimmäisiä kyselyitä."

# %%
from pathlib import Path
import duckdb

# %%
db_path = Path("data/vr_trains.duckdb")
conn = duckdb.connect(str(db_path))
conn.execute("show schemas").fetchdf()

# %%
conn.execute("show tables").fetchdf()

# %%
conn.execute("select * from bronzze.live_trains limit 5").fetchdf()

# %%
conn.close()
